# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## Checking Missing Values

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# From above we can conclude tha there is no any missing values in the datset
# checking + or - correlation between the features
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
plt.subplots(figsize=(12,8))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
Q1 = df.Newspaper.quantile(0.25)
Q3 = df.Newspaper.quantile(0.75)
Q1,Q3
# Out:
# (12.75, 45.1)

# %%
IQR = Q3-Q1
IQR
# Out:
# 32.35

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (-35.775000000000006, 93.625)

# %%
df_clean_data = df[(df.Newspaper>lower_limit)&(df.Newspaper<upper_limit)]
df_clean_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [198 rows x 4 columns]

# %%
plt.subplots(figsize=(12,8))
sns.boxplot(data=df_clean_data)
# Out:
# <Axes: >

# %% [markdown]
# ## Independent and Dependent features

# %%
x = df_clean_data.iloc[:,:-1]  #Independent features
y = df_clean_data.iloc[:,-1]   #Dependent feature

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [198 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 198, dtype: float64

# %%
# Train test split 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 52   216.4   41.7       39.6
# 170   50.0   11.6       18.4
# 39   228.0   37.7       32.0
# 32    97.2    1.5       30.0
# 98   289.7   42.3       51.2
# ..     ...    ...        ...
# 108   13.1    0.4       25.6
# 14   204.1   32.9       46.0
# 93   250.9   36.5       72.3
# 181  218.5    5.4       27.4
# 104  238.2   34.3        5.3
#
# [138 rows x 3 columns]

# %%
y_train
# Out:
# 52     22.6
# 170     8.4
# 39     21.5
# 32     13.2
# 98     25.4
#        ...
# 108     5.3
# 14     19.0
# 93     22.2
# 181    17.2
# 104    20.7
# Name: Sales, Length: 138, dtype: float64

# %%
# checking for multicollinearity means feature should not be much correlated to the other feature
x_train.corr()
# Out:
#                  TV     Radio  Newspaper
# TV         1.000000  0.033738   0.107394
# Radio      0.033738  1.000000   0.381660
# Newspaper  0.107394  0.381660   1.000000

# %%
sns.heatmap(x_train.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Standardizaion Of dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("The slopes or coefficients of best fit line is:",regression.coef_)
print("The intercept:",regression.intercept_)
# Out:
# The slopes or coefficients of best fit line is: [4.53513837 1.51117625 0.28171709]
# The intercept: 15.321739130434786

# %%
# Prediction for test data
y_pred = regression.predict(x_test)

# %%
y_pred
# Out:
# array([ 8.73969911, 13.75335674, 24.26389703, 11.16892835,  9.50004235,
#        21.24519808, 20.14018828, 12.84035266, 15.05911045, 20.84351926,
#        15.97502712, 20.46105223,  8.33229443, 13.96351058,  8.91254222,
#        10.81480272,  9.56597467, 15.74521707,  9.81079412, 11.60048512,
#        12.78415132, 17.05650468, 23.49039705,  7.0915867 , 18.56528679,
#        20.87167705,  8.42400623, 18.53046438,  7.50501077, 14.88068637,
#        18.7516656 , 14.02820959,  8.95890606, 13.14928652, 19.16988387,
#        17.70215559, 16.80809561, 14.41227827, 19.68628284, 17.60911962,
#        18.83005652, 10.94596006, 13.57079614, 10.35155019,  7.40156599,
#         7.85517472, 16.56186863, 17.92963578, 10.24287104, 23.22758852,
#        17.85870892, 16.77473452, 20.10467498,  7.15728689,  6.47057843,
#        15.51181495, 11.82344571, 23.57266497, 13.38245303, 12.35015635])

# %% [markdown]
# ## Performance Metrics

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print(mae)
print(mse)
print(rmse)
# Out:
# 1.2161870225534057
# 2.4507719627368107
# 1.5654941592790472

# %% [markdown]
# ## Accuracy

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9151626818586047

# %%
# print adjusted R^2
print(1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1))
# Out:
# 0.9106178255296014

# %%
# Assumption
# plot a scatter  plot for prediction
plt.scatter(y_test,y_pred)

# %%
# Residuals
residuals = y_test-y_pred
residuals
# Out:
# 66     2.260301
# 116   -1.553357
# 17     0.136103
# 143   -0.768928
# 158   -2.200042
# 128    3.454802
# 142   -0.040188
# 31    -0.940353
# 19    -0.459110
# 169   -0.843519
# 160    0.424973
# 15     1.938948
# 56    -2.832294
# 57    -0.763511
# 117    0.487458
# 46    -0.214803
# 126   -2.965975
# 9     -0.145217
# 149    0.289206
# 86     0.399515
# 115   -0.184151
# 163    0.943495
# 61     0.709603
# 189   -0.391587
# 74    -1.565287
# 69     1.428323
# 121   -1.424006
# 165   -1.630464
# 119   -0.905011
# 177    1.819314
# 70    -0.451666
# 77     0.171790
# 127    2.941094
# 83     0.450713
# 25    -2.169884
# 193    1.897844
# 97     3.691904
# 173    2.287722
# 20    -1.686283
# 152   -1.009120
# 139    1.869943
# 5     -3.745960
# 67    -0.170796
# 140    0.548450
# 106   -0.201566
# 172   -0.255175
# 99     0.638131
# 113    2.970364
# 12    -1.042871
# 36     2.172411
# 187   -0.558709
# 43     1.125265
# 68    -1.204675
# 195    0.442713
# 76     0.429422
# 96     1.188185
# 79    -0.823446
# 30    -2.172665
# 161   -0.082453
# 164   -0.450156
# Name: Sales, dtype: float64

# %%
sns.displot(residuals,kde=True)

# %%
# scatter plot with respect to prediction and residuals
# uniform distribution
plt.scatter(y_pred,residuals)

# %%
plt.subplots(figsize=(15,5))
sns.boxplot(data=x_train)
# Out:
# <Axes: >

# %%
x_train
# Out:
# array([[ 0.76807913,  1.23908448,  0.42482539],
#        [-1.18416556, -0.75800892, -0.5912547 ],
#        [ 0.90417311,  0.97369   ,  0.06057026],
#        [-0.63040385, -1.42812996, -0.03528635],
#        [ 1.6280523 ,  1.27889365,  0.98079374],
#        [ 0.83847257, -1.30206758, -0.84527472],
#        [ 1.67380804,  0.31020383, -1.38686458],
#        [-1.56077046,  0.96705514, -0.43788412],
#        [-0.88499345, -0.81108781, -1.18556569],
#        [ 1.04613321, -0.41963097, -0.37557732],
#        [ 0.50175729,  0.82108818,  2.15024441],
#        [-1.43523549, -1.42812996,  0.10849857],
#        [ 1.51659603, -0.85753184, -0.44746978],
#        [-1.56898303,  1.51774867,  1.84829608],
#        [ 1.04378677,  1.22581475, -0.58646187],
#        [-1.20411037,  1.59073215, -1.06574493],
#        [ 0.06649119, -1.35514648, -1.07533059],
#        [-0.01328804, -1.44139968, -0.30847769],
#        [ 0.6343316 ,  1.46466978, -0.53374073],
#        [ 0.57332395, -1.32197217,  0.18518386],
#        [ 1.04261354, -1.25562355,  0.29541896],
#        [ 1.63978454, -1.25562355, -1.06574493],
#        [-0.36056233, -0.22721998, -0.91716718],
#        [ 0.29057697, -0.50588417, -1.35810759],
#        [ 0.78333104,  0.69502581,  1.35463453],
#        [ 0.73405564,  1.32533768,  0.14684122],
#        [ 1.1435108 ,  0.47607537, -0.50019092],
#        [ 1.55648564,  1.25898906,  1.69971833],
#        [-0.19513775, -1.20254466, -1.02740228],
#        [-1.66988029, -1.38832079, -1.42520722],
#        [-0.62688418, -1.02340339, -1.12805172],
#        [-1.14310273, -1.39495565, -0.44746978],
#        [ 0.15917589, -0.14096677,  0.79866618],
#        [ 0.80796875,  0.69502581,  0.68843107],
#        [-0.95890656, -0.16750622, -0.59604753],
#        [-0.25262573, -1.14946576,  0.02702045],
#        [ 1.47787964,  1.71679452,  0.53026766],
#        [-1.47043221,  1.05994321, -1.02740228],
#        [ 0.65544963, -1.18264007, -0.54332639],
#        [ 1.6034146 ,  1.32533768,  1.96811684],
#        [-0.23268092,  1.31206796, -0.08800748],
#        [ 0.56276494,  1.74996883,  1.40256283],
#        [ 1.22563648,  0.25712493, -1.20952984],
#        [-0.59286068, -0.89070615, -1.30059363],
#        [-0.66560057, -1.20254466, -1.08491625],
#        [ 0.70120536,  0.42963134, -1.02740228],
#        [-0.98589071, -0.75137406,  0.29062613],
#        [-0.48257763,  1.64381104,  0.9903794 ],
#        [-1.61591199, -0.47270986,  0.90410845],
#        [ 0.70237859,  1.76323856,  0.33376161],
#        [ 0.43957642, -0.3267429 , -0.24617089],
#        [-1.56898303, -1.25562355,  0.04139894],
#        [ 1.34061243, -1.33524189,  0.58778163],
#        [-1.26511802,  0.24385521,  0.20914801],
#        [-0.22564158, -0.30683832,  0.18518386],
#        [ 1.58464302, -0.6054071 , -1.29580079],
#        [-1.24869288,  1.07984779,  0.68843107],
#        [ 0.37152943,  1.53765326,  1.34025604],
#        [-0.35117654, -0.9703245 ,  0.86097298],
#        [-1.67222674,  0.27702952, -1.37248608],
#        [ 0.23895512,  1.10638724,  0.33376161],
#        [-0.15290169,  1.55092298,  1.35463453],
#        [ 0.83847257, -1.24235383,  0.91369411],
#        [-0.29603501,  0.92061111,  2.32278631],
#        [-0.73482078,  0.16423687,  2.04480213],
#        [-1.5725027 ,  1.37178171,  2.81165503],
#        [-0.32653884,  0.76800929, -0.87882453],
#        [ 0.9522753 , -0.95705477, -1.05615926],
#        [ 1.01445617, -1.18927493, -0.34682034],
#        [-1.30735408,  1.1992753 , -1.19515135],
#        [-1.45635353,  0.6618515 , -0.54811922],
#        [-1.61708521, -1.50111344, -0.24617089],
#        [ 0.62377258,  0.65521664,  0.73156655],
#        [ 1.1728414 ,  0.89407166,  1.992081  ],
#        [ 0.79271683, -1.16937035, -0.15989994],
#        [ 1.02384196,  0.7481047 , -1.21911551]])

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(x_train,y_train)
# Out:
# LassoCV(cv=5)

# %%
lassocv.predict(x_test)
# Out:
# array([ 8.76666911, 13.76255624, 24.22523775, 11.18496299,  9.50505037,
#        21.2298523 , 20.12116858, 12.84615043, 15.06364695, 20.84230096,
#        15.97514335, 20.43044522,  8.34499632, 13.97356731,  8.94335397,
#        10.829749  ,  9.56813391, 15.75508051,  9.82790738, 11.61390529,
#        12.77852929, 17.05519864, 23.45302065,  7.11992783, 18.56248292,
#        20.85060384,  8.43561146, 18.50991151,  7.5312137 , 14.88588472,
#        18.7369775 , 14.03551282,  8.99189835, 13.14531283, 19.17100684,
#        17.69858605, 16.80806204, 14.42699467, 19.66494089, 17.60892028,
#        18.82349481, 10.93204164, 13.58591988, 10.37325653,  7.42724103,
#         7.88083678, 16.54625663, 17.9308462 , 10.23917318, 23.20830379,
#        17.85442012, 16.77787709, 20.09749702,  7.19200447,  6.50540923,
#        15.52744151, 11.84106539, 23.54452349, 13.37617782, 12.37013951])

# %%
lassocv.alpha_
# Out:
# 0.01314760792921807

# %%
y_pred = lassocv.predict(x_test)
plt.scatter(y_test,y_pred)

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("Score:",score)
# Out:
# Mean Absolute Error: 1.216957373716182
# Mean Squared Error: 2.448822240513215
# Score: 0.9152301745535946

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV()
ridgecv.fit(x_train,y_train)
y_pred = ridgecv.predict(x_test)
plt.scatter(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error:",mae)
print("Mean Squared Error:",mse)
print("Score:",score)
# Out:
# Mean Absolute Error: 1.2170157541416695
# Mean Squared Error: 2.4540861850220055
# Score: 0.9150479548523082

# %% [markdown]
# ## Usin SVR

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

# %%
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.8493749640140069
# 1.5720973946524635

# %%
# Hyper parameter Tuning with SVR
from sklearn.model_selection import GridSearchCV
# defining parameter range
param_grid = {'C':[0.1,1,10,100,1000],
              'gamma':[1,0.1,0.01,0.001,0.0001],
              'kernel':['rbf']}

# %%
grid = GridSearchCV(SVR(),param_grid=param_grid,refit=True,cv=5,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.228 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.053 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.219 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.157 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.132 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.359 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.171 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.330 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.285 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.277 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.071 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=rbf;, score=-0.172 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.065 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.059 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.004 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.007 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.251 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.007 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.006 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=rbf;, score=-0.061 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.259 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.000 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.001 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=rbf;, score=-0.068 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.788 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.640 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.762 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.614 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.652 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.744 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.838 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.542 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.379 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.495 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.482 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.481 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.076 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=rbf;, score=-0.167 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.069 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.063 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.008 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.007 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.250 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.007 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.007 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.060 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.926 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.898 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.939 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.807 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.946 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.905 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.789 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.852 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.921 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.558 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.407 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.514 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.511 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.076 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=rbf;, score=-0.166 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.070 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.063 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.009 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.844 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.842 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.928 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.841 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.893 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.880 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.931 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.893 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.791 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.922 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.905 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.561 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.408 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.514 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.514 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.503 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.836 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.772 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.781 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.868 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.927 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.934 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.879 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.882 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.794 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.866 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.939 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.918 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.891 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.791 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.846 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.922 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.905 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid_predict = grid.predict(x_test)

# %%
# Higher Accuracy than Linear Regression 
from sklearn.metrics import r2_score,mean_absolute_error
print(r2_score(y_test,grid_predict))
print(mean_absolute_error(y_test,grid_predict))
# Out:
# 0.9376436631198756
# 0.9275182796821125
